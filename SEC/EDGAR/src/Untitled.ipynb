# %%
import os
import numpy as np
import pandas as pd

# %%
DIR_DATA_CSV_GAAP = "../data/csv/gaap"
YEAR = 2010
QTR = 1

# %%
df = pd.read_csv(
    f"{DIR_DATA_CSV_GAAP}/{YEAR}QTR{QTR}_GAAP.gz",
    sep="|",
    dtype={'Accession':str}
)
df = df[df['CIK'] == 1000697]
#df.sort_values(['CIK', 'Year', 'Quarter'])
df
# Out:
#         CIK           Accession  Year  Quarter   FS  \
# 0   1000697  000095012310017583  2010        1   pl
# 1   1000697  000095012310017583  2010        1   pl
# 2   1000697  000095012310017583  2010        1   pl
# 3   1000697  000095012310017583  2010        1   pl
# 4   1000697  000095012310017583  2010        1   pl
# 5   1000697  000095012310017583  2010        1  NaN
# 6   1000697  000095012310017583  2010        1  NaN
# 7   1000697  000095012310017583  2010        1   pl
# 8   1000697  000095012310017583  2010        1   pl
# 9   1000697  000095012310017583  2010        1  NaN
# 10  1000697  000095012310017583  2010        1   bs
# 11  1000697  000095012310017583  2010        1  NaN
# 12  1000697  000095012310017583  2010        1  NaN
# 13  1000697  000095012310017583  2010        1  NaN
# 14  1000697  000095012310017583  2010        1  NaN
# 15  1000697  000095012310017583  2010        1   bs
# 16  1000697  000095012310017583  2010        1  NaN
# 17  1000697  000095012310017583  2010        1  NaN
# 18  1000697  000095012310017583  2010        1  NaN
# 19  1000697  000095012310017583  2010        1  NaN
# 20  1000697  000095012310017583  2010        1   bs
# 21  1000697  000095012310017583  2010        1  NaN
# 22  1000697  000095012310017583  2010        1   bs
# 23  1000697  000095012310017583  2010        1  NaN
# 24  1000697  000095012310017583  2010        1  NaN
# 25  1000697  000095012310017583  2010        1   bs
# 26  1000697  000095012310017583  2010        1  NaN
# 27  1000697  000095012310017583  2010        1  NaN
# 28  1000697  000095012310017583  2010        1  NaN
# 29  1000697  000095012310017583  2010        1   bs
# 30  1000697  000095012310017583  2010        1   bs
#
#                              Rep    Type  \
# 0                 operating_cost   debit
# 1                   gross_profit    calc
# 2           operating_expense_rd   debit
# 3          operating_expense_sga   debit
# 4               operating_income    calc
# 5                            NaN   debit
# 6                            NaN   debit
# 7                     net_income    calc
# 8             shares_outstanding    fact
# 9                            NaN  metric
# 10           cash_and_equivalent  credit
# 11                           NaN  credit
# 12                           NaN  credit
# 13                           NaN  credit
# 14                           NaN  credit
# 15                current_assets    calc
# 16                           NaN  credit
# 17                           NaN  credit
# 18                           NaN  credit
# 19                           NaN  credit
# 20                  total_assets    calc
# 21                           NaN   debit
# 22           current_liabilities    calc
# 23                           NaN   debit
# 24                           NaN   debit
# 25             total_liabilities    calc
# 26                           NaN   debit
# 27                           NaN   debit
# 28                           NaN   debit
# 29           stockholders_equity    calc
# 30  total_equity_and_liabilities    calc
#
#                                                  Name         Value    Unit  \
# 0                  us-gaap:costofgoodsandservicessold  5.948820e+08     USD
# 1                                 us-gaap:grossprofit  9.038180e+08     USD
# 2               us-gaap:researchanddevelopmentexpense  7.715400e+07     USD
# 3      us-gaap:sellinggeneralandadministrativeexpense  4.214030e+08     USD
# 4                         us-gaap:operatingincomeloss  3.946020e+08     USD
# 5                             us-gaap:interestexpense -1.098600e+07     USD
# 6                     us-gaap:incometaxexpensebenefit  6.333900e+07     USD
# 7                                  us-gaap:profitloss  3.233130e+08     USD
# 8                us-gaap:commonstocksharesoutstanding  9.411800e+07  Shares
# 9                       us-gaap:earningspersharebasic  3.370000e+00  USDEPS
# 10      us-gaap:cashandcashequivalentsatcarryingvalue  3.411110e+08     USD
# 11                       us-gaap:shortterminvestments  2.891460e+08     USD
# 12               us-gaap:accountsreceivablenetcurrent  3.142470e+08     USD
# 13                               us-gaap:inventorynet  1.786660e+08     USD
# 14                         us-gaap:otherassetscurrent  4.920600e+07     USD
# 15                              us-gaap:assetscurrent  1.172376e+09     USD
# 16               us-gaap:propertyplantandequipmentnet  2.109260e+08     USD
# 17                                   us-gaap:goodwill  2.930770e+08     USD
# 18       us-gaap:intangibleassetsnetexcludinggoodwill  1.821650e+08     USD
# 19                      us-gaap:otherassetsnoncurrent  4.938700e+07     USD
# 20                                     us-gaap:assets  1.907931e+09     USD
# 21                     us-gaap:accountspayablecurrent  4.957300e+07     USD
# 22                         us-gaap:liabilitiescurrent  3.945680e+08     USD
# 23                     us-gaap:longtermdebtnoncurrent  5.000000e+08     USD
# 24                 us-gaap:otherliabilitiesnoncurrent  2.276600e+07     USD
# 25                                us-gaap:liabilities  1.058982e+09     USD
# 26                           us-gaap:commonstockvalue  1.488000e+06     USD
# 27         us-gaap:retainedearningsaccumulateddeficit  2.236716e+09     USD
# 28  us-gaap:accumulatedothercomprehensiveincomelos...  1.557400e+07     USD
# 29  us-gaap:stockholdersequityincludingportionattr...  8.489490e+08     USD
# 30           us-gaap:liabilitiesandstockholdersequity  1.907931e+09     USD
#
#     Decimals                       Context
# 0       -3.0   TwelveMonthsEnded_31Dec2009
# 1       -3.0   TwelveMonthsEnded_31Dec2009
# 2       -3.0   TwelveMonthsEnded_31Dec2009
# 3       -3.0   TwelveMonthsEnded_31Dec2009
# 4       -3.0   TwelveMonthsEnded_31Dec2009
# 5       -3.0   TwelveMonthsEnded_31Dec2009
# 6       -3.0   TwelveMonthsEnded_31Dec2009
# 7       -3.0   TwelveMonthsEnded_31Dec2009
# 8       -3.0  TwelveMonthsEnded_31Dec20092
# 9        2.0   TwelveMonthsEnded_31Dec2009
# 10      -3.0  TwelveMonthsEnded_31Dec20092
# 11      -3.0  TwelveMonthsEnded_31Dec20092
# 12      -3.0  TwelveMonthsEnded_31Dec20092
# 13      -3.0  TwelveMonthsEnded_31Dec20092
# 14      -3.0  TwelveMonthsEnded_31Dec20092
# 15      -3.0  TwelveMonthsEnded_31Dec20092
# 16      -3.0  TwelveMonthsEnded_31Dec20092
# 17      -3.0  TwelveMonthsEnded_31Dec20092
# 18      -3.0  TwelveMonthsEnded_31Dec20092
# 19      -3.0  TwelveMonthsEnded_31Dec20092
# 20      -3.0  TwelveMonthsEnded_31Dec20092
# 21      -3.0  TwelveMonthsEnded_31Dec20092
# 22      -3.0  TwelveMonthsEnded_31Dec20092
# 23      -3.0  TwelveMonthsEnded_31Dec20092
# 24      -3.0  TwelveMonthsEnded_31Dec20092
# 25      -3.0  TwelveMonthsEnded_31Dec20092
# 26      -3.0  TwelveMonthsEnded_31Dec20092
# 27      -3.0  TwelveMonthsEnded_31Dec20092
# 28      -3.0  TwelveMonthsEnded_31Dec20092
# 29      -3.0  TwelveMonthsEnded_31Dec20092
# 30      -3.0  TwelveMonthsEnded_31Dec20092

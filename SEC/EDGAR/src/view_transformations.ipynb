# %%
import os
import numpy as np
import pandas as pd

# %%
YEAR = 2010
QTR = 1

# %% [markdown]
# # List

# %%
DIR_DATA_CSV_LIST = "../data/csv/listing"

# %%
listing = pd.read_csv(
    f"{DIR_DATA_CSV_LIST}/{YEAR}QTR{QTR}_LIST.gz",
    sep="|",
    dtype={'Accession':str}
)
listing
# Out:
#        CIK                    Company Name Form Type  Date Filed  \
# 0  1000697                WATERS CORP /DE/      10-K  2010-02-26
# 1  1001039                 WALT DISNEY CO/      10-Q  2010-02-09
# 2  1001082               DISH Network CORP      10-K  2010-03-01
# 3  1001838           SOUTHERN COPPER CORP/      10-K  2010-02-26
# 4  1002638                  OPEN TEXT CORP      10-Q  2010-02-04
# 5  1002910                     AMEREN CORP      10-K  2010-02-26
# 6  1004155               AGL RESOURCES INC      10-K  2010-02-04
# 7  1004440  CONSTELLATION ENERGY GROUP INC      10-K  2010-02-26
#
#                                             Filename
# 0  https://sec.gov/Archives/edgar/data/1000697/00...
# 1  https://sec.gov/Archives/edgar/data/1001039/00...
# 2  https://sec.gov/Archives/edgar/data/1001082/00...
# 3  https://sec.gov/Archives/edgar/data/1001838/00...
# 4  https://sec.gov/Archives/edgar/data/1002638/00...
# 5  https://sec.gov/Archives/edgar/data/1002910/00...
# 6  https://sec.gov/Archives/edgar/data/1004155/00...
# 7  https://sec.gov/Archives/edgar/data/1004440/00...

# %% [markdown]
# # XBRL

# %%
DIR_DATA_CSV_XBRL = "../data/csv/xbrl"

# %%
xbrl = pd.read_csv(
    f"{DIR_DATA_CSV_XBRL}/{YEAR}QTR{QTR}_XBRL.gz",
    sep="|",
    dtype={'Accession':str}
)
xbrl
# Out:
#        CIK                    Company Name Form Type  Date Filed  Year  \
# 0  1000697                WATERS CORP /DE/      10-K  2010-02-26  2010
# 1  1001039                 WALT DISNEY CO/      10-Q  2010-02-09  2010
# 2  1001082               DISH Network CORP      10-K  2010-03-01  2010
# 3  1001838           SOUTHERN COPPER CORP/      10-K  2010-02-26  2010
# 4  1002638                  OPEN TEXT CORP      10-Q  2010-02-04  2010
# 5  1002910                     AMEREN CORP      10-K  2010-02-26  2010
# 6  1004155               AGL RESOURCES INC      10-K  2010-02-04  2010
# 7  1004440  CONSTELLATION ENERGY GROUP INC      10-K  2010-02-26  2010
#
#    Quarter                                           Filename  \
# 0        1  https://sec.gov/Archives/edgar/data/1000697/00...
# 1        1  https://sec.gov/Archives/edgar/data/1001039/00...
# 2        1  https://sec.gov/Archives/edgar/data/1001082/00...
# 3        1  https://sec.gov/Archives/edgar/data/1001838/00...
# 4        1  https://sec.gov/Archives/edgar/data/1002638/00...
# 5        1  https://sec.gov/Archives/edgar/data/1002910/00...
# 6        1  https://sec.gov/Archives/edgar/data/1004155/00...
# 7        1  https://sec.gov/Archives/edgar/data/1004440/00...
#
#                                           Filepath
# 0   1000697/000095012310017583/wat-20091231.xml.gz
# 1   1001039/000119312510025949/dis-20100102.xml.gz
# 2  1001082/000095012310018671/dish-20091231.xml.gz
# 3  1001838/000110465910010334/scco-20091231.xml.gz
# 4  1002638/000119312510021715/otex-20091231.xml.gz
# 5   1002910/000119312510043155/aee-20091231.xml.gz
# 6   1004155/000100415510000016/agl-20091231.xml.gz
# 7   1004440/000104746910001515/ceg-20091231.xml.gz

# %% [markdown]
# # GAAP

# %%
DIR_DATA_CSV_GAAP = "../data/csv/gaap"

# %%
gaap = pd.read_csv(
    f"{DIR_DATA_CSV_GAAP}/{YEAR}QTR{QTR}_GAAP.gz",
    sep="|",
    dtype={'Accession':str}
)
#df = df[df['CIK'] == 1000697]
#df.sort_values(['CIK', 'Year', 'Quarter'])
gaap
# Out:
#          CIK           Accession  Year  Quarter   FS  \
# 0    1000697  000095012310017583  2010        1   pl
# 1    1000697  000095012310017583  2010        1   pl
# 2    1000697  000095012310017583  2010        1   pl
# 3    1000697  000095012310017583  2010        1   pl
# 4    1000697  000095012310017583  2010        1   pl
# ..       ...                 ...   ...      ...  ...
# 221  1004440  000104746910001515  2010        1  NaN
# 222  1004440  000104746910001515  2010        1  NaN
# 223  1004440  000104746910001515  2010        1  NaN
# 224  1004440  000104746910001515  2010        1   bs
# 225  1004440  000104746910001515  2010        1   bs
#
#                               Rep   Type  \
# 0                  operating_cost  debit
# 1                    gross_profit   calc
# 2            operating_expense_rd  debit
# 3           operating_expense_sga  debit
# 4                operating_income   calc
# ..                            ...    ...
# 221                           NaN  debit
# 222                           NaN  debit
# 223                           NaN  debit
# 224           stockholders_equity   calc
# 225  total_equity_and_liabilities   calc
#
#                                                   Name         Value Unit  \
# 0                   us-gaap:costofgoodsandservicessold  5.948820e+08  USD
# 1                                  us-gaap:grossprofit  9.038180e+08  USD
# 2                us-gaap:researchanddevelopmentexpense  7.715400e+07  USD
# 3       us-gaap:sellinggeneralandadministrativeexpense  4.214030e+08  USD
# 4                          us-gaap:operatingincomeloss  3.946020e+08  USD
# ..                                                 ...           ...  ...
# 221                     us-gaap:longtermdebtnoncurrent  4.814000e+09  USD
# 222                 us-gaap:otherliabilitiesnoncurrent  3.888000e+08  USD
# 223                           us-gaap:minorityinterest  7.530000e+07  USD
# 224  us-gaap:stockholdersequityincludingportionattr...  3.229600e+09  USD
# 225           us-gaap:liabilitiesandstockholdersequity  2.354440e+10  USD
#
#      Decimals                      Context
# 0        -3.0  TwelveMonthsEnded_31Dec2009
# 1        -3.0  TwelveMonthsEnded_31Dec2009
# 2        -3.0  TwelveMonthsEnded_31Dec2009
# 3        -3.0  TwelveMonthsEnded_31Dec2009
# 4        -3.0  TwelveMonthsEnded_31Dec2009
# ..        ...                          ...
# 221      -5.0                        I2009
# 222      -5.0                        I2009
# 223      -5.0                        I2009
# 224      -5.0      I2009_CommonStockMember
# 225      -5.0                        I2009
#
# [226 rows x 12 columns]

# %%
a = [1,2,3]
a[::-1]
# Out:
# [3, 2, 1]
